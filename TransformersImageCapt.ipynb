# %% [markdown]
# # Transformers

# %% [markdown]
# ## Import Libraries

# %%
import string
import numpy as np
import pandas as pd
from numpy import array
from PIL import Image
import pickle

import matplotlib.pyplot as plt
import sys, time, os, warnings
warnings.filterwarnings("ignore")
import re

import keras
import tensorflow as tf
from tqdm import tqdm
from nltk.translate.bleu_score import sentence_bleu

from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense, BatchNormalization
from keras.layers import LSTM
from keras.layers import Embedding
from keras.layers import Dropout
from keras.layers.merge import add
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import load_img, img_to_array
from keras.preprocessing.text import Tokenizer

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data loading and Preprocessing

# %%
image_path = "../input/flickr8k/Images"
dir_Flickr_text = "../input/flickr8k-text/flickr8k.token.txt"
jpgs = os.listdir(image_path)

print("Total Images in Dataset = {}".format(len(jpgs)))
# Out:
# Total Images in Dataset = 8091

# %%
file = open(dir_Flickr_text,'r')
text = file.read()
file.close()

datatxt = []
for line in text.split('\n'):
   col = line.split('\t')
   if len(col) == 1:
       continue
   w = col[0].split("#")
   datatxt.append(w + [col[1].lower()])

data = pd.DataFrame(datatxt,columns=["filename","index","caption"])
data = data.reindex(columns =['index','filename','caption'])
data = data[data.filename != '2258277193_586949ec62.jpg.1']
uni_filenames = np.unique(data.filename.values)

data.head()
# Out:
#   index                   filename  \
# 0     0  1000268201_693b08cb0e.jpg
# 1     1  1000268201_693b08cb0e.jpg
# 2     2  1000268201_693b08cb0e.jpg
# 3     3  1000268201_693b08cb0e.jpg
# 4     4  1000268201_693b08cb0e.jpg
#
#                                              caption
# 0  a child in a pink dress is climbing up a set o...
# 1              a girl going into a wooden building .
# 2   a little girl climbing into a wooden playhouse .
# 3  a little girl climbing the stairs to her playh...
# 4  a little girl in a pink dress going into a woo...

# %%
npic = 5
npix = 224
target_size = (npix,npix,3)
count = 1

fig = plt.figure(figsize=(10,20))
for jpgfnm in uni_filenames[10:14]:
   filename = image_path + '/' + jpgfnm
   captions = list(data["caption"].loc[data["filename"]==jpgfnm].values)
   image_load = load_img(filename, target_size=target_size)
   ax = fig.add_subplot(npic,2,count,xticks=[],yticks=[])
   ax.imshow(image_load)
   count += 1

   ax = fig.add_subplot(npic,2,count)
   plt.axis('off')
   ax.plot()
   ax.set_xlim(0,1)
   ax.set_ylim(0,len(captions))
   for i, caption in enumerate(captions):
       ax.text(0,i,caption,fontsize=20)
   count += 1
plt.show()

# %%
vocabulary = []
for txt in data.caption.values:
   vocabulary.extend(txt.split())
print('Vocabulary Size: %d' % len(set(vocabulary)))
# Out:
# Vocabulary Size: 8918

# %%
def remove_punctuation(text_original):
   text_no_punctuation = text_original.translate(string.punctuation)
   return(text_no_punctuation)

def remove_single_character(text):
   text_len_more_than1 = ""
   for word in text.split():
       if len(word) > 1:
           text_len_more_than1 += " " + word
   return(text_len_more_than1)

def remove_numeric(text):
   text_no_numeric = ""
   for word in text.split():
       isalpha = word.isalpha()
       if isalpha:
           text_no_numeric += " " + word
   return(text_no_numeric)

def text_clean(text_original):
   text = remove_punctuation(text_original)
   text = remove_single_character(text)
   text = remove_numeric(text)
   return(text)

for i, caption in enumerate(data.caption.values):
   newcaption = text_clean(caption)
   data["caption"].iloc[i] = newcaption

# %%
clean_vocabulary = []
for txt in data.caption.values:
   clean_vocabulary.extend(txt.split())
print('Clean Vocabulary Size: %d' % len(set(clean_vocabulary)))
# Out:
# Clean Vocabulary Size: 8357

# %%
PATH = "../input/flickr8k/Images/"
all_captions = []
for caption  in data["caption"].astype(str):
   caption = '<start> ' + caption+ ' <end>'
   all_captions.append(caption)

all_captions[:10]
# Out:
# ['<start>  child in pink dress is climbing up set of stairs in an entry way <end>',
#  '<start>  girl going into wooden building <end>',
#  '<start>  little girl climbing into wooden playhouse <end>',
#  '<start>  little girl climbing the stairs to her playhouse <end>',
#  '<start>  little girl in pink dress going into wooden cabin <end>',
#  '<start>  black dog and spotted dog are fighting <end>',
#  '<start>  black dog and dog playing with each other on the road <end>',
#  '<start>  black dog and white dog with brown spots are staring at each other in the street <end>',
#  '<start>  two dogs of different breeds looking at each other on the road <end>',
#  '<start>  two dogs on pavement moving toward each other <end>']

# %%
all_img_name_vector = []
for annot in data["filename"]:
   full_image_path = PATH + annot
   all_img_name_vector.append(full_image_path)

all_img_name_vector[:10]
# Out:
# ['../input/flickr8k/Images/1000268201_693b08cb0e.jpg',
#  '../input/flickr8k/Images/1000268201_693b08cb0e.jpg',
#  '../input/flickr8k/Images/1000268201_693b08cb0e.jpg',
#  '../input/flickr8k/Images/1000268201_693b08cb0e.jpg',
#  '../input/flickr8k/Images/1000268201_693b08cb0e.jpg',
#  '../input/flickr8k/Images/1001773457_577c3a7d70.jpg',
#  '../input/flickr8k/Images/1001773457_577c3a7d70.jpg',
#  '../input/flickr8k/Images/1001773457_577c3a7d70.jpg',
#  '../input/flickr8k/Images/1001773457_577c3a7d70.jpg',
#  '../input/flickr8k/Images/1001773457_577c3a7d70.jpg']

# %%
print(f"len(all_img_name_vector) : {len(all_img_name_vector)}")
print(f"len(all_captions) : {len(all_captions)}")
# Out:
# len(all_img_name_vector) : 40455
# len(all_captions) : 40455

# %%
def data_limiter(num,total_captions,all_img_name_vector):
   train_captions, img_name_vector = shuffle(total_captions,all_img_name_vector,random_state=1)
   train_captions = train_captions[:num]
   img_name_vector = img_name_vector[:num]
   return train_captions,img_name_vector

train_captions,img_name_vector = data_limiter(40000,all_captions,all_img_name_vector)

# %% [markdown]
# ## Model Definition

# %%
def load_image(image_path):
   img = tf.io.read_file(image_path)
   img = tf.image.decode_jpeg(img, channels=3)
   img = tf.image.resize(img, (299, 299))
   img = tf.keras.applications.inception_v3.preprocess_input(img)
   return img, image_path

image_model = tf.keras.applications.InceptionV3(include_top=False, weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output
image_features_extract_model = tf.keras.Model(new_input, hidden_layer)
# Out:
# 2022-08-18 15:46:17.582076: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-18 15:46:17.713032: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-18 15:46:17.713962: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-18 15:46:17.715699: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-18 15:46:17.716098: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-18 15:46:17.717063: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-18 15:46:17.717952: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-18 15:46:19.976069: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-18 15:46:19.976937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-18 15:46:19.977651: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-18 15:46:19.978278: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step
# 87924736/87910968 [==============================] - 0s 0us/step

# %%
encode_train = sorted(set(img_name_vector))
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(64)

# %%
# %%time
for img, path in tqdm(image_dataset):
    batch_features = image_features_extract_model(img)
    batch_features = tf.reshape(batch_features,
                             (batch_features.shape[0], -1, batch_features.shape[3]))
    
    for bf, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
    #     print("."+path_of_feature[24:])
        np.save("."+path_of_feature[24:], bf.numpy())
# Out:
#   0%|          | 0/127 [00:00<?, ?it/s]2022-08-18 15:46:23.885178: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-08-18 15:46:25.494639: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 100%|██████████| 127/127 [01:21<00:00,  1.55it/s]
# CPU times: user 1min, sys: 8 s, total: 1min 8s
# Wall time: 1min 21s

# %%
top_k = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                 oov_token="<unk>",
                                                 filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')

tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

train_seqs = tokenizer.texts_to_sequences(train_captions)
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
img_name_train, img_name_val, cap_train, cap_val = train_test_split(img_name_vector,cap_vector, test_size=0.2, random_state=0)

# %%
for i in range(len(img_name_train)):
    img_name_train[i] = "."+img_name_train[i][24:]

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 1000
num_steps = len(img_name_train) // BATCH_SIZE

def map_func(img_name, cap):
   img_tensor = np.load(img_name.decode('utf-8')+'.npy')
   return img_tensor, cap

dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))
dataset = dataset.map(lambda item1, item2: tf.numpy_function(map_func, [item1, item2], [tf.float32, tf.int32]),num_parallel_calls=tf.data.experimental.AUTOTUNE)
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## Positional Encoding

# %%
def get_angles(pos, i, d_model):
   angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
   return pos * angle_rates

def positional_encoding_1d(position, d_model):
   angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                           np.arange(d_model)[np.newaxis, :],
                           d_model)

   angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
   angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
   pos_encoding = angle_rads[np.newaxis, ...]
   return tf.cast(pos_encoding, dtype=tf.float32)

def positional_encoding_2d(row,col,d_model):
   assert d_model % 2 == 0
   row_pos = np.repeat(np.arange(row),col)[:,np.newaxis]
   col_pos = np.repeat(np.expand_dims(np.arange(col),0),row,axis=0).reshape(-1,1)

   angle_rads_row = get_angles(row_pos,np.arange(d_model//2)[np.newaxis,:],d_model//2)
   angle_rads_col = get_angles(col_pos,np.arange(d_model//2)[np.newaxis,:],d_model//2)

   angle_rads_row[:, 0::2] = np.sin(angle_rads_row[:, 0::2])
   angle_rads_row[:, 1::2] = np.cos(angle_rads_row[:, 1::2])
   angle_rads_col[:, 0::2] = np.sin(angle_rads_col[:, 0::2])
   angle_rads_col[:, 1::2] = np.cos(angle_rads_col[:, 1::2])
   pos_encoding = np.concatenate([angle_rads_row,angle_rads_col],axis=1)[np.newaxis, ...]
   return tf.cast(pos_encoding, dtype=tf.float32)

# %% [markdown]
# ## Multi-Head Attention

# %%
def create_padding_mask(seq):
   seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
   return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

def create_look_ahead_mask(size):
   mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
   return mask  # (seq_len, seq_len)

def scaled_dot_product_attention(q, k, v, mask):
   matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)
   dk = tf.cast(tf.shape(k)[-1], tf.float32)
   scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

   if mask is not None:
      scaled_attention_logits += (mask * -1e9) 

   attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1) 
   output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

   return output, attention_weights

class MultiHeadAttention(tf.keras.layers.Layer):
   def __init__(self, d_model, num_heads):
      super(MultiHeadAttention, self).__init__()
      self.num_heads = num_heads
      self.d_model = d_model
      assert d_model % self.num_heads == 0
      self.depth = d_model // self.num_heads
      self.wq = tf.keras.layers.Dense(d_model)
      self.wk = tf.keras.layers.Dense(d_model)
      self.wv = tf.keras.layers.Dense(d_model)
      self.dense = tf.keras.layers.Dense(d_model)

   def split_heads(self, x, batch_size):
      x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
      return tf.transpose(x, perm=[0, 2, 1, 3])

   def call(self, v, k, q, mask=None):
      batch_size = tf.shape(q)[0]
      q = self.wq(q)  # (batch_size, seq_len, d_model)
      k = self.wk(k)  # (batch_size, seq_len, d_model)
      v = self.wv(v)  # (batch_size, seq_len, d_model)

      q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
      k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
      v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

      scaled_attention, attention_weights = scaled_dot_product_attention(q, k, v, mask)
      scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q,      num_heads, depth)

      concat_attention = tf.reshape(scaled_attention,
                                 (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

      output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)
      return output, attention_weights

def point_wise_feed_forward_network(d_model, dff):
   return tf.keras.Sequential([
                tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
                tf.keras.layers.Dense(d_model) ]) # (batch_size, seq_len, d_model)])

# %% [markdown]
# ##  Encoder-Decoder Layer

# %%
class EncoderLayer(tf.keras.layers.Layer):
   def __init__(self, d_model, num_heads, dff, rate=0.1):
      super(EncoderLayer, self).__init__()
      self.mha = MultiHeadAttention(d_model, num_heads)
      self.ffn = point_wise_feed_forward_network(d_model, dff)

      self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
      self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

      self.dropout1 = tf.keras.layers.Dropout(rate)
      self.dropout2 = tf.keras.layers.Dropout(rate)


   def call(self, x, training, mask=None):
      attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
      attn_output = self.dropout1(attn_output, training=training)
      out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

      ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
      ffn_output = self.dropout2(ffn_output, training=training)
      out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)
      return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
   def __init__(self, d_model, num_heads, dff, rate=0.1):
      super(DecoderLayer, self).__init__()
      self.mha1 = MultiHeadAttention(d_model, num_heads)
      self.mha2 = MultiHeadAttention(d_model, num_heads)

      self.ffn = point_wise_feed_forward_network(d_model, dff)

      self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
      self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
      self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

      self.dropout1 = tf.keras.layers.Dropout(rate)
      self.dropout2 = tf.keras.layers.Dropout(rate)
      self.dropout3 = tf.keras.layers.Dropout(rate)

   def call(self, x, enc_output, training,look_ahead_mask=None, padding_mask=None):
      attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
      attn1 = self.dropout1(attn1, training=training)
      out1 = self.layernorm1(attn1 + x)

      attn2, attn_weights_block2 = self.mha2(enc_output, enc_output, out1, padding_mask) 
      attn2 = self.dropout2(attn2, training=training)
      out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)

      ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
      ffn_output = self.dropout3(ffn_output, training=training)
      out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)

      return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
   def __init__(self, num_layers, d_model, num_heads, dff, row_size,col_size,rate=0.1):
      super(Encoder, self).__init__()
      self.d_model = d_model
      self.num_layers = num_layers

      self.embedding = tf.keras.layers.Dense(self.d_model,activation='relu')
      self.pos_encoding = positional_encoding_2d(row_size,col_size,self.d_model)

      self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
      self.dropout = tf.keras.layers.Dropout(rate)

   def call(self, x, training, mask=None):
      seq_len = tf.shape(x)[1]
      x = self.embedding(x)  # (batch_size, input_seq_len(H*W), d_model)
      x += self.pos_encoding[:, :seq_len, :]
      x = self.dropout(x, training=training)

      for i in range(self.num_layers):
         x = self.enc_layers[i](x, training, mask)

      return x  # (batch_size, input_seq_len, d_model)

# %%
class Decoder(tf.keras.layers.Layer):
   def __init__(self, num_layers,d_model,num_heads,dff, target_vocab_size, maximum_position_encoding,   rate=0.1):
      super(Decoder, self).__init__()
      self.d_model = d_model
      self.num_layers = num_layers

      self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
      self.pos_encoding = positional_encoding_1d(maximum_position_encoding, d_model)

      self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate)
                         for _ in range(num_layers)]
      self.dropout = tf.keras.layers.Dropout(rate)

   def call(self, x, enc_output, training,look_ahead_mask=None, padding_mask=None):
      seq_len = tf.shape(x)[1]
      attention_weights = {}

      x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
      x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
      x += self.pos_encoding[:, :seq_len, :]
      x = self.dropout(x, training=training)

      for i in range(self.num_layers):
         x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                            look_ahead_mask, padding_mask)
         
         attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
         attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

      return x, attention_weights

# %% [markdown]
# ## Transformer

# %%
class Transformer(tf.keras.Model):
   def __init__(self, num_layers, d_model, num_heads, dff,row_size,col_size,
              target_vocab_size,max_pos_encoding, rate=0.1):
      super(Transformer, self).__init__()
      self.encoder = Encoder(num_layers, d_model, num_heads, dff,row_size,col_size, rate)
      self.decoder = Decoder(num_layers, d_model, num_heads, dff,
                          target_vocab_size,max_pos_encoding, rate)
      self.final_layer = tf.keras.layers.Dense(target_vocab_size)

   def call(self, inp, tar, training,look_ahead_mask=None,dec_padding_mask=None,enc_padding_mask=None   ):
      enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model      )
      dec_output, attention_weights = self.decoder(
      tar, enc_output, training, look_ahead_mask, dec_padding_mask)
      final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)
      return final_output, attention_weights

# %%
num_layer = 4
d_model = 512
dff = 2048
num_heads = 8
row_size = 8
col_size = 8
target_vocab_size = top_k + 1
dropout_rate = 0.1

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
   def __init__(self, d_model, warmup_steps=4000):
      super(CustomSchedule, self).__init__()
      self.d_model = d_model
      self.d_model = tf.cast(self.d_model, tf.float32)
      self.warmup_steps = warmup_steps

   def __call__(self, step):
      arg1 = tf.math.rsqrt(step)
      arg2 = step * (self.warmup_steps ** -1.5)
      return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,
                                    epsilon=1e-9)
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
   mask = tf.math.logical_not(tf.math.equal(real, 0))
   loss_ = loss_object(real, pred)
   mask = tf.cast(mask, dtype=loss_.dtype)
   loss_ *= mask
   return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')
transformer = Transformer(num_layer,d_model,num_heads,dff,row_size,col_size,target_vocab_size, max_pos_encoding=target_vocab_size,rate=dropout_rate)

# %% [markdown]
# ## Model Training

# %%
def create_masks_decoder(tar):
   look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
   dec_target_padding_mask = create_padding_mask(tar)
   combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)
   return combined_mask

# %%
@tf.function
def train_step(img_tensor, tar):
   tar_inp = tar[:, :-1]
   tar_real = tar[:, 1:]
   dec_mask = create_masks_decoder(tar_inp)
   with tf.GradientTape() as tape:
      predictions, _ = transformer(img_tensor, tar_inp,True, dec_mask)
      loss = loss_function(tar_real, predictions)

   gradients = tape.gradient(loss, transformer.trainable_variables)   
   optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
   train_loss(loss)
   train_accuracy(tar_real, predictions)

# %%
for epoch in range(30):
   start = time.time()
   train_loss.reset_states()
   train_accuracy.reset_states()
   for (batch, (img_tensor, tar)) in enumerate(dataset):
      train_step(img_tensor, tar)
      if batch % 50 == 0:
         print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
         epoch + 1, batch, train_loss.result(), train_accuracy.result()))

   print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1,
                                               train_loss.result(),
                                               train_accuracy.result()))
   print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 8.5078 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 8.1056 Accuracy 0.0220
# Epoch 1 Batch 100 Loss 7.7262 Accuracy 0.0266
# Epoch 1 Batch 150 Loss 7.4299 Accuracy 0.0288
# Epoch 1 Batch 200 Loss 7.1377 Accuracy 0.0318
# Epoch 1 Batch 250 Loss 6.8625 Accuracy 0.0354
# Epoch 1 Batch 300 Loss 6.6115 Accuracy 0.0391
# Epoch 1 Batch 350 Loss 6.3929 Accuracy 0.0425
# Epoch 1 Batch 400 Loss 6.2014 Accuracy 0.0459
# Epoch 1 Batch 450 Loss 6.0311 Accuracy 0.0491
# Epoch 1 Loss 5.8832 Accuracy 0.0519
# Time taken for 1 epoch: 89.21444320678711 secs
#
# Epoch 2 Batch 0 Loss 4.4005 Accuracy 0.0781
# Epoch 2 Batch 50 Loss 4.3983 Accuracy 0.0809
# Epoch 2 Batch 100 Loss 4.3389 Accuracy 0.0830
# Epoch 2 Batch 150 Loss 4.2882 Accuracy 0.0836
# Epoch 2 Batch 200 Loss 4.2349 Accuracy 0.0844
# Epoch 2 Batch 250 Loss 4.1920 Accuracy 0.0853
# Epoch 2 Batch 300 Loss 4.1539 Accuracy 0.0861
# Epoch 2 Batch 350 Loss 4.1121 Accuracy 0.0870
# Epoch 2 Batch 400 Loss 4.0760 Accuracy 0.0878
# Epoch 2 Batch 450 Loss 4.0406 Accuracy 0.0886
# Epoch 2 Loss 4.0107 Accuracy 0.0892
# Time taken for 1 epoch: 80.99919819831848 secs
#
# Epoch 3 Batch 0 Loss 3.5348 Accuracy 0.0938
# Epoch 3 Batch 50 Loss 3.6838 Accuracy 0.0965
# Epoch 3 Batch 100 Loss 3.6637 Accuracy 0.0979
# Epoch 3 Batch 150 Loss 3.6399 Accuracy 0.0981
# Epoch 3 Batch 200 Loss 3.6155 Accuracy 0.0988
# Epoch 3 Batch 250 Loss 3.5976 Accuracy 0.0993
# Epoch 3 Batch 300 Loss 3.5805 Accuracy 0.0997
# Epoch 3 Batch 350 Loss 3.5642 Accuracy 0.1000
# Epoch 3 Batch 400 Loss 3.5470 Accuracy 0.1002
# Epoch 3 Batch 450 Loss 3.5303 Accuracy 0.1007
# Epoch 3 Loss 3.5172 Accuracy 0.1010
# Time taken for 1 epoch: 81.49022006988525 secs
#
# Epoch 4 Batch 0 Loss 3.4760 Accuracy 0.1030
# Epoch 4 Batch 50 Loss 3.3633 Accuracy 0.1058
# Epoch 4 Batch 100 Loss 3.3532 Accuracy 0.1065
# Epoch 4 Batch 150 Loss 3.3375 Accuracy 0.1063
# Epoch 4 Batch 200 Loss 3.3242 Accuracy 0.1062
# Epoch 4 Batch 250 Loss 3.3118 Accuracy 0.1066
# Epoch 4 Batch 300 Loss 3.3022 Accuracy 0.1070
# Epoch 4 Batch 350 Loss 3.2915 Accuracy 0.1073
# Epoch 4 Batch 400 Loss 3.2819 Accuracy 0.1074
# Epoch 4 Batch 450 Loss 3.2721 Accuracy 0.1077
# Epoch 4 Loss 3.2643 Accuracy 0.1080
# Time taken for 1 epoch: 81.48477864265442 secs
#
# Epoch 5 Batch 0 Loss 3.2348 Accuracy 0.1133
# Epoch 5 Batch 50 Loss 3.1696 Accuracy 0.1117
# Epoch 5 Batch 100 Loss 3.1616 Accuracy 0.1121
# Epoch 5 Batch 150 Loss 3.1551 Accuracy 0.1122
# Epoch 5 Batch 200 Loss 3.1374 Accuracy 0.1120
# Epoch 5 Batch 250 Loss 3.1361 Accuracy 0.1120
# Epoch 5 Batch 300 Loss 3.1267 Accuracy 0.1124
# Epoch 5 Batch 350 Loss 3.1198 Accuracy 0.1124
# Epoch 5 Batch 400 Loss 3.1131 Accuracy 0.1125
# Epoch 5 Batch 450 Loss 3.1063 Accuracy 0.1130
# Epoch 5 Loss 3.1017 Accuracy 0.1130
# Time taken for 1 epoch: 80.83074903488159 secs
#
# Epoch 6 Batch 0 Loss 2.8890 Accuracy 0.1299
# Epoch 6 Batch 50 Loss 3.0241 Accuracy 0.1158
# Epoch 6 Batch 100 Loss 3.0198 Accuracy 0.1163
# Epoch 6 Batch 150 Loss 3.0163 Accuracy 0.1160
# Epoch 6 Batch 200 Loss 3.0095 Accuracy 0.1157
# Epoch 6 Batch 250 Loss 3.0113 Accuracy 0.1155
# Epoch 6 Batch 300 Loss 3.0052 Accuracy 0.1158
# Epoch 6 Batch 350 Loss 2.9991 Accuracy 0.1160
# Epoch 6 Batch 400 Loss 2.9969 Accuracy 0.1159
# Epoch 6 Batch 450 Loss 2.9900 Accuracy 0.1161
# Epoch 6 Loss 2.9855 Accuracy 0.1163
# Time taken for 1 epoch: 81.27672529220581 secs
#
# Epoch 7 Batch 0 Loss 2.9769 Accuracy 0.1123
# Epoch 7 Batch 50 Loss 2.9149 Accuracy 0.1192
# Epoch 7 Batch 100 Loss 2.9253 Accuracy 0.1193
# Epoch 7 Batch 150 Loss 2.9253 Accuracy 0.1185
# Epoch 7 Batch 200 Loss 2.9154 Accuracy 0.1184
# Epoch 7 Batch 250 Loss 2.9211 Accuracy 0.1181
# Epoch 7 Batch 300 Loss 2.9199 Accuracy 0.1180
# Epoch 7 Batch 350 Loss 2.9160 Accuracy 0.1182
# Epoch 7 Batch 400 Loss 2.9121 Accuracy 0.1181
# Epoch 7 Batch 450 Loss 2.9062 Accuracy 0.1184
# Epoch 7 Loss 2.9062 Accuracy 0.1184
# Time taken for 1 epoch: 81.22345399856567 secs
#
# Epoch 8 Batch 0 Loss 2.8146 Accuracy 0.1138
# Epoch 8 Batch 50 Loss 2.8716 Accuracy 0.1187
# Epoch 8 Batch 100 Loss 2.8736 Accuracy 0.1196
# Epoch 8 Batch 150 Loss 2.8687 Accuracy 0.1192
# Epoch 8 Batch 200 Loss 2.8658 Accuracy 0.1191
# Epoch 8 Batch 250 Loss 2.8728 Accuracy 0.1187
# Epoch 8 Batch 300 Loss 2.8708 Accuracy 0.1190
# Epoch 8 Batch 350 Loss 2.8695 Accuracy 0.1190
# Epoch 8 Batch 400 Loss 2.8636 Accuracy 0.1190
# Epoch 8 Batch 450 Loss 2.8609 Accuracy 0.1192
# Epoch 8 Loss 2.8617 Accuracy 0.1192
# Time taken for 1 epoch: 81.11971497535706 secs
#
# Epoch 9 Batch 0 Loss 2.8500 Accuracy 0.1226
# Epoch 9 Batch 50 Loss 2.8558 Accuracy 0.1188
# Epoch 9 Batch 100 Loss 2.8495 Accuracy 0.1202
# Epoch 9 Batch 150 Loss 2.8485 Accuracy 0.1201
# Epoch 9 Batch 200 Loss 2.8440 Accuracy 0.1196
# Epoch 9 Batch 250 Loss 2.8372 Accuracy 0.1197
# Epoch 9 Batch 300 Loss 2.8288 Accuracy 0.1201
# Epoch 9 Batch 350 Loss 2.8233 Accuracy 0.1202
# Epoch 9 Batch 400 Loss 2.8159 Accuracy 0.1203
# Epoch 9 Batch 450 Loss 2.8065 Accuracy 0.1207
# Epoch 9 Loss 2.8018 Accuracy 0.1208
# Time taken for 1 epoch: 81.23875379562378 secs
#
# Epoch 10 Batch 0 Loss 2.7612 Accuracy 0.1333
# Epoch 10 Batch 50 Loss 2.7373 Accuracy 0.1216
# Epoch 10 Batch 100 Loss 2.7389 Accuracy 0.1234
# Epoch 10 Batch 150 Loss 2.7322 Accuracy 0.1234
# Epoch 10 Batch 200 Loss 2.7247 Accuracy 0.1233
# Epoch 10 Batch 250 Loss 2.7224 Accuracy 0.1236
# Epoch 10 Batch 300 Loss 2.7121 Accuracy 0.1240
# Epoch 10 Batch 350 Loss 2.7058 Accuracy 0.1241
# Epoch 10 Batch 400 Loss 2.6969 Accuracy 0.1244
# Epoch 10 Batch 450 Loss 2.6885 Accuracy 0.1248
# Epoch 10 Loss 2.6838 Accuracy 0.1249
# Time taken for 1 epoch: 81.39495921134949 secs
#
# Epoch 11 Batch 0 Loss 2.4850 Accuracy 0.1226
# Epoch 11 Batch 50 Loss 2.6116 Accuracy 0.1274
# Epoch 11 Batch 100 Loss 2.6083 Accuracy 0.1288
# Epoch 11 Batch 150 Loss 2.6038 Accuracy 0.1285
# Epoch 11 Batch 200 Loss 2.6024 Accuracy 0.1279
# Epoch 11 Batch 250 Loss 2.6003 Accuracy 0.1280
# Epoch 11 Batch 300 Loss 2.5946 Accuracy 0.1280
# Epoch 11 Batch 350 Loss 2.5880 Accuracy 0.1285
# Epoch 11 Batch 400 Loss 2.5810 Accuracy 0.1285
# Epoch 11 Batch 450 Loss 2.5739 Accuracy 0.1290
# Epoch 11 Loss 2.5683 Accuracy 0.1292
# Time taken for 1 epoch: 81.30639123916626 secs
#
# Epoch 12 Batch 0 Loss 2.4490 Accuracy 0.1284
# Epoch 12 Batch 50 Loss 2.4948 Accuracy 0.1317
# Epoch 12 Batch 100 Loss 2.4960 Accuracy 0.1334
# Epoch 12 Batch 150 Loss 2.4958 Accuracy 0.1327
# Epoch 12 Batch 200 Loss 2.4915 Accuracy 0.1327
# Epoch 12 Batch 250 Loss 2.4918 Accuracy 0.1327
# Epoch 12 Batch 300 Loss 2.4876 Accuracy 0.1328
# Epoch 12 Batch 350 Loss 2.4804 Accuracy 0.1330
# Epoch 12 Batch 400 Loss 2.4741 Accuracy 0.1332
# Epoch 12 Batch 450 Loss 2.4680 Accuracy 0.1335
# Epoch 12 Loss 2.4639 Accuracy 0.1335
# Time taken for 1 epoch: 80.91927409172058 secs
#
# Epoch 13 Batch 0 Loss 2.3311 Accuracy 0.1411
# Epoch 13 Batch 50 Loss 2.3923 Accuracy 0.1363
# Epoch 13 Batch 100 Loss 2.3969 Accuracy 0.1371
# Epoch 13 Batch 150 Loss 2.3902 Accuracy 0.1369
# Epoch 13 Batch 200 Loss 2.3912 Accuracy 0.1362
# Epoch 13 Batch 250 Loss 2.3889 Accuracy 0.1366
# Epoch 13 Batch 300 Loss 2.3853 Accuracy 0.1366
# Epoch 13 Batch 350 Loss 2.3767 Accuracy 0.1371
# Epoch 13 Batch 400 Loss 2.3730 Accuracy 0.1371
# Epoch 13 Batch 450 Loss 2.3667 Accuracy 0.1375
# Epoch 13 Loss 2.3626 Accuracy 0.1375
# Time taken for 1 epoch: 81.44982075691223 secs
#
# Epoch 14 Batch 0 Loss 2.2695 Accuracy 0.1338
# Epoch 14 Batch 50 Loss 2.3127 Accuracy 0.1402
# Epoch 14 Batch 100 Loss 2.2981 Accuracy 0.1410
# Epoch 14 Batch 150 Loss 2.2952 Accuracy 0.1409
# Epoch 14 Batch 200 Loss 2.2912 Accuracy 0.1402
# Epoch 14 Batch 250 Loss 2.2903 Accuracy 0.1405
# Epoch 14 Batch 300 Loss 2.2841 Accuracy 0.1407
# Epoch 14 Batch 350 Loss 2.2789 Accuracy 0.1411
# Epoch 14 Batch 400 Loss 2.2734 Accuracy 0.1412
# Epoch 14 Batch 450 Loss 2.2679 Accuracy 0.1415
# Epoch 14 Loss 2.2634 Accuracy 0.1416
# Time taken for 1 epoch: 81.16011476516724 secs
#
# Epoch 15 Batch 0 Loss 2.1882 Accuracy 0.1426
# Epoch 15 Batch 50 Loss 2.2223 Accuracy 0.1436
# Epoch 15 Batch 100 Loss 2.2183 Accuracy 0.1443
# Epoch 15 Batch 150 Loss 2.2071 Accuracy 0.1446
# Epoch 15 Batch 200 Loss 2.2012 Accuracy 0.1447
# Epoch 15 Batch 250 Loss 2.1976 Accuracy 0.1450
# Epoch 15 Batch 300 Loss 2.1940 Accuracy 0.1453
# Epoch 15 Batch 350 Loss 2.1853 Accuracy 0.1457
# Epoch 15 Batch 400 Loss 2.1797 Accuracy 0.1458
# Epoch 15 Batch 450 Loss 2.1738 Accuracy 0.1463
# Epoch 15 Loss 2.1697 Accuracy 0.1464
# Time taken for 1 epoch: 80.30550384521484 secs
#
# Epoch 16 Batch 0 Loss 2.2357 Accuracy 0.1362
# Epoch 16 Batch 50 Loss 2.1410 Accuracy 0.1465
# Epoch 16 Batch 100 Loss 2.1230 Accuracy 0.1477
# Epoch 16 Batch 150 Loss 2.1137 Accuracy 0.1485
# Epoch 16 Batch 200 Loss 2.1076 Accuracy 0.1486
# Epoch 16 Batch 250 Loss 2.1062 Accuracy 0.1490
# Epoch 16 Batch 300 Loss 2.1003 Accuracy 0.1494
# Epoch 16 Batch 350 Loss 2.0958 Accuracy 0.1495
# Epoch 16 Batch 400 Loss 2.0893 Accuracy 0.1498
# Epoch 16 Batch 450 Loss 2.0827 Accuracy 0.1501
# Epoch 16 Loss 2.0783 Accuracy 0.1504
# Time taken for 1 epoch: 81.40151190757751 secs
#
# Epoch 17 Batch 0 Loss 1.9811 Accuracy 0.1504
# Epoch 17 Batch 50 Loss 2.0242 Accuracy 0.1528
# Epoch 17 Batch 100 Loss 2.0258 Accuracy 0.1540
# Epoch 17 Batch 150 Loss 2.0204 Accuracy 0.1540
# Epoch 17 Batch 200 Loss 2.0157 Accuracy 0.1536
# Epoch 17 Batch 250 Loss 2.0104 Accuracy 0.1537
# Epoch 17 Batch 300 Loss 2.0096 Accuracy 0.1541
# Epoch 17 Batch 350 Loss 2.0038 Accuracy 0.1544
# Epoch 17 Batch 400 Loss 2.0001 Accuracy 0.1545
# Epoch 17 Batch 450 Loss 1.9962 Accuracy 0.1547
# Epoch 17 Loss 1.9924 Accuracy 0.1548
# Time taken for 1 epoch: 81.40097236633301 secs
#
# Epoch 18 Batch 0 Loss 2.0171 Accuracy 0.1406
# Epoch 18 Batch 50 Loss 1.9489 Accuracy 0.1568
# Epoch 18 Batch 100 Loss 1.9514 Accuracy 0.1572
# Epoch 18 Batch 150 Loss 1.9373 Accuracy 0.1583
# Epoch 18 Batch 200 Loss 1.9365 Accuracy 0.1576
# Epoch 18 Batch 250 Loss 1.9339 Accuracy 0.1580
# Epoch 18 Batch 300 Loss 1.9288 Accuracy 0.1584
# Epoch 18 Batch 350 Loss 1.9230 Accuracy 0.1586
# Epoch 18 Batch 400 Loss 1.9175 Accuracy 0.1587
# Epoch 18 Batch 450 Loss 1.9124 Accuracy 0.1590
# Epoch 18 Loss 1.9083 Accuracy 0.1591
# Time taken for 1 epoch: 81.0501492023468 secs
#
# Epoch 19 Batch 0 Loss 1.9664 Accuracy 0.1587
# Epoch 19 Batch 50 Loss 1.8791 Accuracy 0.1603
# Epoch 19 Batch 100 Loss 1.8722 Accuracy 0.1620
# Epoch 19 Batch 150 Loss 1.8621 Accuracy 0.1620
# Epoch 19 Batch 200 Loss 1.8548 Accuracy 0.1621
# Epoch 19 Batch 250 Loss 1.8502 Accuracy 0.1623
# Epoch 19 Batch 300 Loss 1.8472 Accuracy 0.1627
# Epoch 19 Batch 350 Loss 1.8428 Accuracy 0.1627
# Epoch 19 Batch 400 Loss 1.8401 Accuracy 0.1629
# Epoch 19 Batch 450 Loss 1.8349 Accuracy 0.1632
# Epoch 19 Loss 1.8305 Accuracy 0.1634
# Time taken for 1 epoch: 81.19780611991882 secs
#
# Epoch 20 Batch 0 Loss 1.7056 Accuracy 0.1689
# Epoch 20 Batch 50 Loss 1.7903 Accuracy 0.1658
# Epoch 20 Batch 100 Loss 1.7881 Accuracy 0.1663
# Epoch 20 Batch 150 Loss 1.7781 Accuracy 0.1667
# Epoch 20 Batch 200 Loss 1.7777 Accuracy 0.1662
# Epoch 20 Batch 250 Loss 1.7721 Accuracy 0.1665
# Epoch 20 Batch 300 Loss 1.7687 Accuracy 0.1669
# Epoch 20 Batch 350 Loss 1.7644 Accuracy 0.1671
# Epoch 20 Batch 400 Loss 1.7590 Accuracy 0.1675
# Epoch 20 Batch 450 Loss 1.7544 Accuracy 0.1676
# Epoch 20 Loss 1.7514 Accuracy 0.1678
# Time taken for 1 epoch: 81.34095311164856 secs
#
# Epoch 21 Batch 0 Loss 1.6599 Accuracy 0.1562
# Epoch 21 Batch 50 Loss 1.7097 Accuracy 0.1702
# Epoch 21 Batch 100 Loss 1.7135 Accuracy 0.1718
# Epoch 21 Batch 150 Loss 1.7070 Accuracy 0.1718
# Epoch 21 Batch 200 Loss 1.7023 Accuracy 0.1714
# Epoch 21 Batch 250 Loss 1.6997 Accuracy 0.1714
# Epoch 21 Batch 300 Loss 1.6958 Accuracy 0.1719
# Epoch 21 Batch 350 Loss 1.6908 Accuracy 0.1720
# Epoch 21 Batch 400 Loss 1.6878 Accuracy 0.1720
# Epoch 21 Batch 450 Loss 1.6851 Accuracy 0.1720
# Epoch 21 Loss 1.6798 Accuracy 0.1724
# Time taken for 1 epoch: 80.67863750457764 secs
#
# Epoch 22 Batch 0 Loss 1.7521 Accuracy 0.1694
# Epoch 22 Batch 50 Loss 1.6342 Accuracy 0.1751
# Epoch 22 Batch 100 Loss 1.6360 Accuracy 0.1760
# Epoch 22 Batch 150 Loss 1.6326 Accuracy 0.1764
# Epoch 22 Batch 200 Loss 1.6299 Accuracy 0.1756
# Epoch 22 Batch 250 Loss 1.6299 Accuracy 0.1757
# Epoch 22 Batch 300 Loss 1.6258 Accuracy 0.1761
# Epoch 22 Batch 350 Loss 1.6219 Accuracy 0.1760
# Epoch 22 Batch 400 Loss 1.6182 Accuracy 0.1761
# Epoch 22 Batch 450 Loss 1.6151 Accuracy 0.1763
# Epoch 22 Loss 1.6129 Accuracy 0.1764
# Time taken for 1 epoch: 80.99922037124634 secs
#
# Epoch 23 Batch 0 Loss 1.5270 Accuracy 0.1660
# Epoch 23 Batch 50 Loss 1.5736 Accuracy 0.1787
# Epoch 23 Batch 100 Loss 1.5812 Accuracy 0.1784
# Epoch 23 Batch 150 Loss 1.5720 Accuracy 0.1788
# Epoch 23 Batch 200 Loss 1.5694 Accuracy 0.1789
# Epoch 23 Batch 250 Loss 1.5667 Accuracy 0.1792
# Epoch 23 Batch 300 Loss 1.5624 Accuracy 0.1795
# Epoch 23 Batch 350 Loss 1.5598 Accuracy 0.1797
# Epoch 23 Batch 400 Loss 1.5537 Accuracy 0.1799
# Epoch 23 Batch 450 Loss 1.5500 Accuracy 0.1803
# Epoch 23 Loss 1.5467 Accuracy 0.1804
# Time taken for 1 epoch: 81.10774660110474 secs
#
# Epoch 24 Batch 0 Loss 1.5067 Accuracy 0.1621
# Epoch 24 Batch 50 Loss 1.5222 Accuracy 0.1829
# Epoch 24 Batch 100 Loss 1.5195 Accuracy 0.1836
# Epoch 24 Batch 150 Loss 1.5112 Accuracy 0.1836
# Epoch 24 Batch 200 Loss 1.5069 Accuracy 0.1834
# Epoch 24 Batch 250 Loss 1.5061 Accuracy 0.1833
# Epoch 24 Batch 300 Loss 1.5032 Accuracy 0.1835
# Epoch 24 Batch 350 Loss 1.4992 Accuracy 0.1838
# Epoch 24 Batch 400 Loss 1.4948 Accuracy 0.1841
# Epoch 24 Batch 450 Loss 1.4906 Accuracy 0.1843
# Epoch 24 Loss 1.4867 Accuracy 0.1845
# Time taken for 1 epoch: 80.87681293487549 secs
#
# Epoch 25 Batch 0 Loss 1.4159 Accuracy 0.1763
# Epoch 25 Batch 50 Loss 1.4536 Accuracy 0.1876
# Epoch 25 Batch 100 Loss 1.4528 Accuracy 0.1881
# Epoch 25 Batch 150 Loss 1.4488 Accuracy 0.1882
# Epoch 25 Batch 200 Loss 1.4457 Accuracy 0.1879
# Epoch 25 Batch 250 Loss 1.4442 Accuracy 0.1878
# Epoch 25 Batch 300 Loss 1.4436 Accuracy 0.1880
# Epoch 25 Batch 350 Loss 1.4399 Accuracy 0.1881
# Epoch 25 Batch 400 Loss 1.4376 Accuracy 0.1878
# Epoch 25 Batch 450 Loss 1.4348 Accuracy 0.1881
# Epoch 25 Loss 1.4313 Accuracy 0.1883
# Time taken for 1 epoch: 81.24969100952148 secs
#
# Epoch 26 Batch 0 Loss 1.4700 Accuracy 0.1851
# Epoch 26 Batch 50 Loss 1.4070 Accuracy 0.1904
# Epoch 26 Batch 100 Loss 1.3970 Accuracy 0.1916
# Epoch 26 Batch 150 Loss 1.3966 Accuracy 0.1915
# Epoch 26 Batch 200 Loss 1.3922 Accuracy 0.1908
# Epoch 26 Batch 250 Loss 1.3871 Accuracy 0.1916
# Epoch 26 Batch 300 Loss 1.3847 Accuracy 0.1916
# Epoch 26 Batch 350 Loss 1.3821 Accuracy 0.1917
# Epoch 26 Batch 400 Loss 1.3793 Accuracy 0.1919
# Epoch 26 Batch 450 Loss 1.3774 Accuracy 0.1920
# Epoch 26 Loss 1.3750 Accuracy 0.1922
# Time taken for 1 epoch: 81.17371153831482 secs
#
# Epoch 27 Batch 0 Loss 1.4243 Accuracy 0.1831
# Epoch 27 Batch 50 Loss 1.3520 Accuracy 0.1941
# Epoch 27 Batch 100 Loss 1.3500 Accuracy 0.1947
# Epoch 27 Batch 150 Loss 1.3448 Accuracy 0.1947
# Epoch 27 Batch 200 Loss 1.3433 Accuracy 0.1941
# Epoch 27 Batch 250 Loss 1.3392 Accuracy 0.1946
# Epoch 27 Batch 300 Loss 1.3368 Accuracy 0.1949
# Epoch 27 Batch 350 Loss 1.3334 Accuracy 0.1950
# Epoch 27 Batch 400 Loss 1.3305 Accuracy 0.1954
# Epoch 27 Batch 450 Loss 1.3274 Accuracy 0.1954
# Epoch 27 Loss 1.3241 Accuracy 0.1957
# Time taken for 1 epoch: 81.31035280227661 secs
#
# Epoch 28 Batch 0 Loss 1.3045 Accuracy 0.1831
# Epoch 28 Batch 50 Loss 1.2858 Accuracy 0.1989
# Epoch 28 Batch 100 Loss 1.2922 Accuracy 0.1996
# Epoch 28 Batch 150 Loss 1.2875 Accuracy 0.1991
# Epoch 28 Batch 200 Loss 1.2856 Accuracy 0.1987
# Epoch 28 Batch 250 Loss 1.2865 Accuracy 0.1986
# Epoch 28 Batch 300 Loss 1.2867 Accuracy 0.1987
# Epoch 28 Batch 350 Loss 1.2840 Accuracy 0.1989
# Epoch 28 Batch 400 Loss 1.2805 Accuracy 0.1991
# Epoch 28 Batch 450 Loss 1.2775 Accuracy 0.1994
# Epoch 28 Loss 1.2738 Accuracy 0.1996
# Time taken for 1 epoch: 80.96357750892639 secs
#
# Epoch 29 Batch 0 Loss 1.2947 Accuracy 0.1934
# Epoch 29 Batch 50 Loss 1.2507 Accuracy 0.2013
# Epoch 29 Batch 100 Loss 1.2506 Accuracy 0.2025
# Epoch 29 Batch 150 Loss 1.2444 Accuracy 0.2031
# Epoch 29 Batch 200 Loss 1.2422 Accuracy 0.2022
# Epoch 29 Batch 250 Loss 1.2388 Accuracy 0.2025
# Epoch 29 Batch 300 Loss 1.2354 Accuracy 0.2029
# Epoch 29 Batch 350 Loss 1.2330 Accuracy 0.2027
# Epoch 29 Batch 400 Loss 1.2310 Accuracy 0.2028
# Epoch 29 Batch 450 Loss 1.2283 Accuracy 0.2031
# Epoch 29 Loss 1.2256 Accuracy 0.2032
# Time taken for 1 epoch: 81.26641130447388 secs
#
# Epoch 30 Batch 0 Loss 1.2071 Accuracy 0.2119
# Epoch 30 Batch 50 Loss 1.2105 Accuracy 0.2051
# Epoch 30 Batch 100 Loss 1.2108 Accuracy 0.2050
# Epoch 30 Batch 150 Loss 1.2051 Accuracy 0.2051
# Epoch 30 Batch 200 Loss 1.2004 Accuracy 0.2047
# Epoch 30 Batch 250 Loss 1.1987 Accuracy 0.2050
# Epoch 30 Batch 300 Loss 1.1974 Accuracy 0.2052
# Epoch 30 Batch 350 Loss 1.1946 Accuracy 0.2053
# Epoch 30 Batch 400 Loss 1.1916 Accuracy 0.2055
# Epoch 30 Batch 450 Loss 1.1890 Accuracy 0.2057
# Epoch 30 Loss 1.1859 Accuracy 0.2059
# Time taken for 1 epoch: 80.67679357528687 secs

# %% [markdown]
# ## BLEU Evaluation

# %%
def evaluate(image):
   temp_input = tf.expand_dims(load_image(image)[0], 0)
   img_tensor_val = image_features_extract_model(temp_input)
   img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))
   start_token = tokenizer.word_index['<start>']
   end_token = tokenizer.word_index['<end>']
   decoder_input = [start_token]
   output = tf.expand_dims(decoder_input, 0) #tokens
   result = [] #word list

   for i in range(100):
      dec_mask = create_masks_decoder(output)
      predictions, attention_weights = transformer(img_tensor_val,output,False,dec_mask)
      predictions = predictions[: ,-1:, :]  # (batch_size, 1, vocab_size)
      predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)
      if predicted_id == end_token:
         return result,tf.squeeze(output, axis=0), attention_weights
      result.append(tokenizer.index_word[int(predicted_id)])
      output = tf.concat([output, predicted_id], axis=-1)

   return result,tf.squeeze(output, axis=0), attention_weights

# %%
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

for i in caption:
   if i=="<unk>":
      caption.remove(i)

for i in real_caption:
   if i=="<unk>":
      real_caption.remove(i)

result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]
real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption

score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")
print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: man in feather hat looking down
# Predicted Caption: the person is wearing red shirt
